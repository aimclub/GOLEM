# %%
from datetime import timedelta
import sys
import os
parentdir = os.getcwd()
# print(parentdir)
# sys.path.insert(0, parentdir)
module_path = os.path.abspath(os.path.join('..'))[:-8]
if module_path not in sys.path:
    sys.path.append(module_path)
from copy import deepcopy
import pandas as pd
from numpy import std, mean, log
from random import choice, sample
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import bamt.preprocessors as pp
import bamt.networks as Nets
from golem.core.optimisers.optimization_parameters import GraphRequirements
from golem.core.dag.verification_rules import has_no_cycle, has_no_self_cycled_nodes
from golem.core.adapter import DirectAdapter
from golem.core.optimisers.genetic.gp_optimizer import EvoGraphOptimizer
from golem.core.optimisers.genetic.gp_params import GPAlgorithmParameters
from golem.core.dag.convert import graph_structure_as_nx_graph
from golem.core.optimisers.genetic.operators.inheritance import GeneticSchemeTypesEnum
from golem.core.optimisers.genetic.operators.selection import SelectionTypesEnum
from golem.core.optimisers.objective.objective import Objective
from golem.core.optimisers.objective.objective_eval import ObjectiveEvaluate
from golem.core.optimisers.optimizer import GraphGenerationParams
from golem.core.dag.linked_graph import LinkedGraph
from golem.core.dag.graph_utils import ordered_subnodes_hierarchy
from math import ceil
from scipy.stats import norm
from itertools import chain
from composite_model import CompositeModel
from composite_node import CompositeNode
from ML import ML_models

# %%
# файл с исходными данными (должен лежать в 'examples/data/')
file = 'asia'
k = 1
# размер популяции 
pop_size = 20
# количество поколений
n_generation = 1000
# вероятность кроссовера
crossover_probability = 0.8
# вероятность мутации
mutation_probability = 0.9
time_m = 1000
n = 1
number = 1

# %% [markdown]
# Задаем fitness-функцию

# %%
def composite_metric(graph: CompositeModel, data: pd.DataFrame):
    try:
        data_all = data
        data_train , data_test = train_test_split(data_all, train_size = 0.8, random_state=42)
        score, len_data = 0, len(data_train)
        for node in graph.nodes:   
            data_of_node_train = data_train[node.content['name']]
            data_of_node_test = data_test[node.content['name']]
            if node.nodes_from == None or node.nodes_from == []:
                if node.content['type'] == 'cont':
                    mu, sigma = mean(data_of_node_train), std(data_of_node_train)
                    score += norm.logpdf(data_of_node_test.values, loc=mu, scale=sigma).sum()
                else:
                    count = data_of_node_train.value_counts()
                    frequency  = log(count / len_data)
                    index = frequency.index.tolist()
                    for value in data_of_node_test:
                        if value in index:
                            score += frequency[value]

            else:
                model, columns, target, idx = node.content['parent_model'](), [n.content['name'] for n in node.nodes_from], data_of_node_train.to_numpy(), data_train.index.to_numpy()
                features = data_train[columns].to_numpy()
                fitted_model = model.fit(features, target)
                
                idx=data_test.index.to_numpy()
                features=data_test[columns].to_numpy()
                target=data_of_node_test.to_numpy()            
                if node.content['type'] == 'cont':
                    predict = fitted_model.predict(features)        
                    mse =  mean_squared_error(target, predict, squared=False) + 0.0000001
                    a = norm.logpdf(target, loc=predict, scale=mse)
                    score += a.sum()                
                else:
                    predict_proba = fitted_model.predict_proba(features)
                    idx = pd.array(list(range(len(target))))
                    li = []
                    
                    for i in idx:
                        a = predict_proba[i]
                        try:
                            b = a[target[i]]
                        except:
                            b = 0.0000001
                        li.append(log(b))
                    score += sum(li)
    except Exception as ax:
        print(ax)
    return -score

# %% [markdown]
# Задаем кроссоверы

# %%
def custom_crossover_exchange_edges(graph_first: CompositeModel, graph_second: CompositeModel, max_depth):

    def find_node(graph: CompositeModel, node):
        name = node.content['name']
        for graph_node in graph.nodes:
            if graph_node.content['name'] == name:
                return graph_node

    num_cros = 100
    try:
        for _ in range(num_cros):
            old_edges1 = []
            old_edges2 = []
            new_graph_first=deepcopy(graph_first)
            new_graph_second=deepcopy(graph_second)

            edges_1 = new_graph_first.operator.get_edges()
            edges_2 = new_graph_second.operator.get_edges()
            count = ceil(min(len(edges_1), len(edges_2))/2)
            choice_edges_1 = sample(edges_1, count)
            choice_edges_2 = sample(edges_2, count)
            
            for pair in choice_edges_1:
                new_graph_first.operator.disconnect_nodes(pair[0], pair[1], False)
            for pair in choice_edges_2:
                new_graph_second.operator.disconnect_nodes(pair[0], pair[1], False)  
            
            old_edges1 = new_graph_first.operator.get_edges()
            old_edges2 = new_graph_second.operator.get_edges()

            new_edges_2 = [[find_node(new_graph_second, i[0]), find_node(new_graph_second, i[1])] for i in choice_edges_1]
            new_edges_1 = [[find_node(new_graph_first, i[0]), find_node(new_graph_first, i[1])] for i in choice_edges_2] 
            for pair in new_edges_1:
                if pair not in old_edges1:
                    new_graph_first.operator.connect_nodes(pair[0], pair[1])
            for pair in new_edges_2:
                if pair not in old_edges2:
                    new_graph_second.operator.connect_nodes(pair[0], pair[1])                                             
            
            if old_edges1 != new_graph_first.operator.get_edges() or old_edges2 != new_graph_second.operator.get_edges():
                break

        if old_edges1 == new_graph_first.operator.get_edges() and new_edges_1!=[] and new_edges_1!=None:
            new_graph_first = deepcopy(graph_first)
        if old_edges2 == new_graph_second.operator.get_edges() and new_edges_2!=[] and new_edges_2!=None:
            new_graph_second = deepcopy(graph_second)
    except Exception as ex:
        print(ex)
    return new_graph_first, new_graph_second

# %%
def custom_crossover_exchange_parents_both(graph_first: CompositeModel, graph_second: CompositeModel, max_depth):
    
    def find_node(graph: CompositeModel, node):
        name = node.content['name']
        for graph_node in graph.nodes:
            if graph_node.content['name'] == name:
                return graph_node
    
    num_cros = 100
    try:
        for _ in range(num_cros):
            old_edges1 = []
            old_edges2 = []
            parents1 = []
            parents2 = []
            new_graph_first=deepcopy(graph_first)
            new_graph_second=deepcopy(graph_second)

            edges = new_graph_second.operator.get_edges()
            flatten_edges = list(chain(*edges))
            nodes_with_parent_or_child=list(set(flatten_edges))
            if nodes_with_parent_or_child!=[]:
                
                selected_node2=choice(nodes_with_parent_or_child)
                parents2=selected_node2.nodes_from

                selected_node1=find_node(new_graph_first, selected_node2)
                parents1=selected_node1.nodes_from
                
                if parents1:
                    for p in parents1:
                        new_graph_first.operator.disconnect_nodes(p, selected_node1, False)
                if parents2:
                    for p in parents2:
                        new_graph_second.operator.disconnect_nodes(p, selected_node2, False)

                old_edges1 = new_graph_first.operator.get_edges()
                old_edges2 = new_graph_second.operator.get_edges()

                if parents2!=[] and parents2!=None:
                    parents_in_first_graph=[find_node(new_graph_first, i) for i in parents2]
                    for parent in parents_in_first_graph:
                        if [parent, selected_node1] not in old_edges1:
                            new_graph_first.operator.connect_nodes(parent, selected_node1)

                if parents1!=[] and parents1!=None:
                    parents_in_second_graph=[find_node(new_graph_second, i) for i in parents1]
                    for parent in parents_in_second_graph:
                        if [parent, selected_node2] not in old_edges2:
                            new_graph_second.operator.connect_nodes(parent, selected_node2)            


            if old_edges1 != new_graph_first.operator.get_edges() or old_edges2 != new_graph_second.operator.get_edges():
                break    
        
        if old_edges1 == new_graph_first.operator.get_edges() and parents2!=[] and parents2!=None:
            new_graph_first = deepcopy(graph_first)                
        if old_edges2 == new_graph_second.operator.get_edges() and parents1!=[] and parents1!=None:
            new_graph_second = deepcopy(graph_second)       

    except Exception as ex:
        print(ex)    
    return new_graph_first, new_graph_second

# %%
def custom_crossover_all_model(graph_first: CompositeModel, graph_second: CompositeModel, max_depth):

    def find_node(graph: CompositeModel, node):
        name = node.content['name']
        for graph_node in graph.nodes:
            if graph_node.content['name'] == name:
                return graph_node    
        
    num_cros = 100
    try:
        for _ in range(num_cros):
            selected_node1=choice(graph_first.nodes)
            if selected_node1.nodes_from == None or selected_node1.nodes_from == []:
                continue
            
            selected_node2=find_node(graph_second, selected_node1)           
            if selected_node2.nodes_from == None or selected_node2.nodes_from == []:
                continue            

            model1 = selected_node1.content['parent_model']
            model2 = selected_node2.content['parent_model']

            selected_node1.content['parent_model'] = model2
            selected_node2.content['parent_model'] = model1

            break

    except Exception as ex:
        print(ex)
    return graph_first, graph_second

# %% [markdown]
# Задаем мутации

# %%
def custom_mutation_add_structure(graph: CompositeModel, **kwargs):
    num_mut = 100
    try:
        for _ in range(num_mut):
            rid = choice(range(len(graph.nodes)))
            random_node = graph.nodes[rid]
            other_random_node = graph.nodes[choice(range(len(graph.nodes)))]
            nodes_not_cycling = (random_node.descriptive_id not in
                                 [n.descriptive_id for n in ordered_subnodes_hierarchy(other_random_node)] and
                                 other_random_node.descriptive_id not in
                                 [n.descriptive_id for n in ordered_subnodes_hierarchy(random_node)])
            if nodes_not_cycling:
                graph.operator.connect_nodes(random_node, other_random_node)
                break

    except Exception as ex:
        graph.log.warn(f'Incorrect connection: {ex}')
    return graph

# %%
def custom_mutation_delete_structure(graph: CompositeModel, **kwargs):
    num_mut = 100
    try:
        for _ in range(num_mut):
            rid = choice(range(len(graph.nodes)))
            random_node = graph.nodes[rid]
            other_random_node = graph.nodes[choice(range(len(graph.nodes)))]
            if random_node.nodes_from is not None and other_random_node in random_node.nodes_from:
                graph.operator.disconnect_nodes(other_random_node, random_node, False)
                break
    except Exception as ex:
        print(ex) 
    return graph

# %%
def custom_mutation_reverse_structure(graph: CompositeModel, **kwargs):
    num_mut = 100
    try:
        for _ in range(num_mut):
            rid = choice(range(len(graph.nodes)))
            random_node = graph.nodes[rid]
            other_random_node = graph.nodes[choice(range(len(graph.nodes)))]
            if random_node.nodes_from is not None and other_random_node in random_node.nodes_from:
                graph.operator.reverse_edge(other_random_node, random_node)   
                break         
    except Exception as ex:
        print(ex)  
    return graph

# %%
def custom_mutation_add_model(graph: CompositeModel, **kwargs):
    try:
        all_nodes = graph.nodes
        nodes_with_parents = [node for node in all_nodes if (node.nodes_from!=[] and node.nodes_from!=None)]
        if nodes_with_parents == []:
            return graph
        node = choice(nodes_with_parents)
        ml_models = ML_models()
        node.content['parent_model'] = ml_models.get_model_by_children_type(node)
    except Exception as ex:
        print(ex)  
    return graph

# %%
def mutation_set1(graph: CompositeModel, **kwargs):
    return custom_mutation_add_model(custom_mutation_add_structure(graph, **kwargs))


def mutation_set2(graph: CompositeModel, **kwargs): 
    return custom_mutation_add_model(custom_mutation_delete_structure(graph, **kwargs))
        

def mutation_set3(graph: CompositeModel, **kwargs):
    return custom_mutation_add_model(custom_mutation_reverse_structure(graph, **kwargs))



def cross_set(graph_first: CompositeModel, graph_second: CompositeModel, max_depth):
    g11, g12 = custom_crossover_exchange_parents_both(graph_first, graph_second, max_depth)
    g21, g22 = custom_crossover_exchange_edges(g11, g12, max_depth)
    g31, g32 = custom_crossover_all_model(g21, g22, max_depth)
    return g31, g32

# %%
def connect_nodes(self, parent: CompositeNode, child: CompositeNode):
    if child.descriptive_id not in [p.descriptive_id for p in ordered_subnodes_hierarchy(parent)]:
        try:
            if child.nodes_from==None or child.nodes_from==[]:
                child.nodes_from = []
                child.nodes_from.append(parent)
                ml_models = ML_models()
                child.content['parent_model'] = ml_models.get_model_by_children_type(child)                
            else:                      
                child.nodes_from.append(parent)
        except Exception as ex:
            print(ex)

def disconnect_nodes(self, node_parent: CompositeNode, node_child: CompositeNode,
                    clean_up_leftovers: bool = True):
    if not node_child.nodes_from or node_parent not in node_child.nodes_from:
        return
    elif node_parent not in self._nodes or node_child not in self._nodes:
        return
    elif len(node_child.nodes_from) == 1:
        node_child.nodes_from = None
    else:
        node_child.nodes_from.remove(node_parent)

    if clean_up_leftovers:
        self._clean_up_leftovers(node_parent)

    self._postprocess_nodes(self, self._nodes)

    if node_child.nodes_from == [] or node_child.nodes_from == None:
        node_child.content['parent_model'] = None


def reverse_edge(self, node_parent: CompositeNode, node_child: CompositeNode):
    self.disconnect_nodes(node_parent, node_child, False)
    self.connect_nodes(node_child, node_parent)


LinkedGraph.reverse_edge = reverse_edge
LinkedGraph.connect_nodes = connect_nodes
LinkedGraph.disconnect_nodes = disconnect_nodes

# %% [markdown]
# Задаем правила на запрет дублирующих узлов

# %%
def _has_no_duplicates(graph: CompositeModel):
    _, labels = graph_structure_as_nx_graph(graph)
    if len(labels.values()) != len(set(labels.values())):
        raise ValueError('Custom graph has duplicates')
    return True

# %% [markdown]
# Функции для расчета SHD

# %%
def child_dict(net: list):
    res_dict = dict()
    for e0, e1 in net:
        if e1 in res_dict:
            res_dict[e1].append(e0)
        else:
            res_dict[e1] = [e0]
    return res_dict

def precision_recall(pred, true_net: list, decimal = 2):

    edges= pred.operator.get_edges()
    struct = []
    for s in edges:
        struct.append((s[0].content['name'], s[1].content['name']))

    pred_net = deepcopy(struct)

    pred_dict = child_dict(pred_net)
    true_dict = child_dict(true_net)
    corr_undir = 0
    corr_dir = 0
    for e0, e1 in pred_net:
        flag = True
        if e1 in true_dict:
            if e0 in true_dict[e1]:
                corr_undir += 1
                corr_dir += 1
                flag = False
        if (e0 in true_dict) and flag:
            if e1 in true_dict[e0]:
                corr_undir += 1
    pred_len = len(pred_net)
    true_len = len(true_net)
    shd = pred_len + true_len - corr_undir - corr_dir
    return {
    'SHD': shd}

# %%
def run_example():

    # загрузка файла
    data = pd.read_csv(sys.path[-1] + 'examples/data/'+file+'.csv')   
    data.drop(['Unnamed: 0'], axis=1, inplace=True)
    data.reset_index(inplace=True, drop=True)
    vertices = list(data.columns)
    
    # кодирование    
    encoder = preprocessing.LabelEncoder()
    p = pp.Preprocessor([('encoder', encoder)])
    discretized_data, _ = p.apply(data)

    # загрузка истинной структуры
    with open(sys.path[-1] + 'examples/data/'+file+'.txt') as f:
        lines = f.readlines()
    true_net = []
    for l in lines:
        e0 = l.split()[0]
        e1 = l.split()[1].split('\n')[0]
        true_net.append((e0, e1))       

    # загрузка файла
    data = pd.read_csv(sys.path[-1] + 'examples/data/'+file+'.csv')   
    data.drop(['Unnamed: 0'], axis=1, inplace=True)
    data.reset_index(inplace=True, drop=True)
    vertices = list(data.columns)
    
    # кодирование
    encoder = preprocessing.LabelEncoder()
    p = pp.Preprocessor([('encoder', encoder)])
    discretized_data, _ = p.apply(data)

    # правила для байесовских сетей: нет петель, нет циклов, нет повторяющихся узлов
    rules = [has_no_self_cycled_nodes, has_no_cycle, _has_no_duplicates]

    # инициализация начальной сети (пустая)
    initial = [CompositeModel(nodes=[CompositeNode(nodes_from=None,
                                                    content={'name': vertex,
                                                            'type': p.nodes_types[vertex],
                                                            'parent_model': None}) 
                                                    for vertex in vertices])] 
    init = initial[0]
   
    # задаем для оптимизатора fitness-функцию
    objective = Objective({'custom': composite_metric})
    objective_eval = ObjectiveEvaluate(objective, data = discretized_data)    

    requirements = GraphRequirements(
        max_arity=100,
        max_depth=100, 
        num_of_generations=n_generation,
        timeout=timedelta(minutes=time_m),
        history_dir = None
        )

    optimiser_parameters = GPAlgorithmParameters(
        pop_size=pop_size,
        crossover_prob=crossover_probability, 
        mutation_prob=mutation_probability,
        genetic_scheme_type = GeneticSchemeTypesEnum.steady_state,
        selection_types = [SelectionTypesEnum.tournament],
        mutation_types = [
        custom_mutation_add_structure, 
        custom_mutation_delete_structure, 
        custom_mutation_reverse_structure, 
        custom_mutation_add_model
        ],

        crossover_types = [
            custom_crossover_exchange_edges,
            custom_crossover_exchange_parents_both,
            custom_crossover_all_model
            ]
    )

    graph_generation_params = GraphGenerationParams(
        adapter=DirectAdapter(base_graph_class=CompositeModel, base_node_class=CompositeNode),
        rules_for_constraint=rules
        )

    optimiser = EvoGraphOptimizer(
        graph_generation_params=graph_generation_params,
        graph_optimizer_params=optimiser_parameters,
        requirements=requirements,
        initial_graphs=[init],
        objective=objective)


    # запуск оптимизатора
    optimized_graph = optimiser.optimise(objective_eval)[0]
    print('\n' + 'Score of optimized graph = ', composite_metric(optimized_graph, discretized_data))
    print('SHD of optimized graph = ', precision_recall(optimized_graph, true_net)['SHD'])


    #  отрисовка полученного графа
    graph = optimized_graph
    name_nodes = [str(n) for n in graph.nodes]
    graph_nodes = filter(lambda x: str(x) in name_nodes, graph.nodes)
    for node in graph_nodes:
        if node.content['parent_model'] != None:
            model_name = str(node.content['parent_model']).split('.')[-1][:-2]
            parents = [n.content['name'] for n in node.nodes_from]
            new_node = CompositeNode(nodes_from=None,
                                        content={'name': model_name,
                                                'type' : 'model',
                                                'parent_model': None})
            graph.add_node(new_node)

            for parent in parents:
                parent = [n for n in graph.nodes if n.content['name'] == parent][0]
                graph.operator.disconnect_nodes(parent, node, False)
                graph.operator.connect_nodes(parent, new_node)   

            graph.operator.connect_nodes(new_node, node)
            graph.operator.sort_nodes()

    size_dict = {}
    color_dict = {}
    for n in graph.nodes:
        if n.content['type'] == 'model':
            size_dict[n.content['name']] = 10
            color_dict[n.content['name']] = 'yellow'
        else:
            size_dict[n.content['name']] = 30
            color_dict[n.content['name']] = 'pink'
    
    graph.show(node_color = color_dict)
    graph.show(engine = 'pyvis', node_color = color_dict, node_size_scale = size_dict,
    save_path=(sys.path[-1] + '\\examples\\composite_bn\\' + 'graph' + '_' + str(k) + '_' + str(file) + '_' + str(number) + '.html'))

# %%
while number <= n:
    run_example() 
    number += 1
# Out:
# 2022-12-20 16:55:17,004 | INFO     | preprocessors.py-scan-0087 | No one column is continuous
# 2022-12-20 16:55:17,032 | INFO     | preprocessors.py-scan-0087 | No one column is continuous
# Generations:   0%|          | 1/1000 [00:00<?, ?gen/s]
# 2022-12-20 16:55:17,060 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 16:55:17,237 - EvoGraphOptimizer - Generation num: 1 size: 1
# 2022-12-20 16:55:17,240 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=583.277>']
# 2022-12-20 16:55:17,382 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 16:55:22,600 - EvoGraphOptimizer - Generation num: 2 size: 20
# 2022-12-20 16:55:22,603 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=540.906>']
# 2022-12-20 16:55:22,606 - EvoGraphOptimizer - Next population size: 40; max graph depth: 100
# 2022-12-20 16:55:22,684 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 16:55:28,373 - EvoGraphOptimizer - Generation num: 3 size: 40
# 2022-12-20 16:55:28,374 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=540.739>']
# 2022-12-20 16:55:28,377 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 16:55:28,650 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 16:55:40,509 - EvoGraphOptimizer - Generation num: 4 size: 55
# 2022-12-20 16:55:40,511 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=534.819>']
# 2022-12-20 16:55:40,514 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 16:55:40,807 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 16:55:56,760 - EvoGraphOptimizer - Generation num: 5 size: 55
# 2022-12-20 16:55:56,763 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=515.246>']
# 2022-12-20 16:55:56,764 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 16:55:57,022 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 16:56:17,755 - EvoGraphOptimizer - Generation num: 6 size: 55
# 2022-12-20 16:56:17,757 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=515.105>']
# 2022-12-20 16:56:17,759 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 16:56:17,993 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 16:56:37,178 - EvoGraphOptimizer - Generation num: 7 size: 55
# 2022-12-20 16:56:37,181 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=515.105>']
# 2022-12-20 16:56:37,182 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 16:56:37,186 - EvoGraphOptimizer - spent time: 1.3 min
# 2022-12-20 16:56:37,189 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 16:56:37,413 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 16:56:55,946 - EvoGraphOptimizer - Generation num: 8 size: 55
# 2022-12-20 16:56:55,947 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=495.169>']
# 2022-12-20 16:56:55,949 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 16:56:56,170 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 16:57:19,528 - EvoGraphOptimizer - Generation num: 9 size: 55
# 2022-12-20 16:57:19,530 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=495.169>']
# 2022-12-20 16:57:19,532 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 16:57:19,536 - EvoGraphOptimizer - spent time: 2.0 min
# 2022-12-20 16:57:19,539 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 16:57:19,854 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 16:57:51,328 - EvoGraphOptimizer - Generation num: 10 size: 55
# 2022-12-20 16:57:51,330 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=495.169>']
# 2022-12-20 16:57:51,331 - EvoGraphOptimizer - no improvements for 2 iterations
# 2022-12-20 16:57:51,335 - EvoGraphOptimizer - spent time: 2.6 min
# 2022-12-20 16:57:51,339 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 16:57:51,560 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 16:58:22,806 - EvoGraphOptimizer - Generation num: 11 size: 55
# 2022-12-20 16:58:22,808 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=493.899>']
# 2022-12-20 16:58:22,810 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 16:58:23,052 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 16:58:58,508 - EvoGraphOptimizer - Generation num: 12 size: 55
# 2022-12-20 16:58:58,509 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=493.899>']
# 2022-12-20 16:58:58,512 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 16:58:58,514 - EvoGraphOptimizer - spent time: 3.7 min
# 2022-12-20 16:58:58,516 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 16:58:58,771 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 16:59:32,009 - EvoGraphOptimizer - Generation num: 13 size: 55
# 2022-12-20 16:59:32,011 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=493.398>']
# 2022-12-20 16:59:32,013 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 16:59:32,235 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:00:09,997 - EvoGraphOptimizer - Generation num: 14 size: 55
# 2022-12-20 17:00:09,999 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=487.686>']
# 2022-12-20 17:00:10,001 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:00:10,247 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:00:51,135 - EvoGraphOptimizer - Generation num: 15 size: 55
# 2022-12-20 17:00:51,138 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=473.503>']
# 2022-12-20 17:00:51,140 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:00:51,367 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:01:30,114 - EvoGraphOptimizer - Generation num: 16 size: 55
# 2022-12-20 17:01:30,116 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=466.331>']
# 2022-12-20 17:01:30,119 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:01:30,341 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:02:15,961 - EvoGraphOptimizer - Generation num: 17 size: 55
# 2022-12-20 17:02:15,963 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=466.331>']
# 2022-12-20 17:02:15,965 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 17:02:15,968 - EvoGraphOptimizer - spent time: 7.0 min
# 2022-12-20 17:02:15,972 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:02:16,189 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:03:01,481 - EvoGraphOptimizer - Generation num: 18 size: 55
# 2022-12-20 17:03:01,483 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=466.200>']
# 2022-12-20 17:03:01,485 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:03:01,701 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:03:49,392 - EvoGraphOptimizer - Generation num: 19 size: 55
# 2022-12-20 17:03:49,394 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=464.312>']
# 2022-12-20 17:03:49,397 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:03:49,634 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:04:41,153 - EvoGraphOptimizer - Generation num: 20 size: 55
# 2022-12-20 17:04:41,156 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=464.312>']
# 2022-12-20 17:04:41,158 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 17:04:41,162 - EvoGraphOptimizer - spent time: 9.4 min
# 2022-12-20 17:04:41,165 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:04:41,435 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:05:34,702 - EvoGraphOptimizer - Generation num: 21 size: 55
# 2022-12-20 17:05:34,704 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=464.312>']
# 2022-12-20 17:05:34,706 - EvoGraphOptimizer - no improvements for 2 iterations
# 2022-12-20 17:05:34,709 - EvoGraphOptimizer - spent time: 10.3 min
# 2022-12-20 17:05:34,714 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:05:35,013 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:06:33,288 - EvoGraphOptimizer - Generation num: 22 size: 55
# 2022-12-20 17:06:33,290 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=464.283>']
# 2022-12-20 17:06:33,293 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:06:33,557 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:07:31,136 - EvoGraphOptimizer - Generation num: 23 size: 55
# 2022-12-20 17:07:31,139 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=463.522>']
# 2022-12-20 17:07:31,140 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:07:31,405 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:08:25,715 - EvoGraphOptimizer - Generation num: 24 size: 55
# 2022-12-20 17:08:25,717 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=461.142>']
# 2022-12-20 17:08:25,719 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:08:25,962 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:09:18,015 - EvoGraphOptimizer - Generation num: 25 size: 55
# 2022-12-20 17:09:18,018 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=461.142>']
# 2022-12-20 17:09:18,020 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 17:09:18,022 - EvoGraphOptimizer - spent time: 14.0 min
# 2022-12-20 17:09:18,026 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:09:18,276 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:10:00,144 - EvoGraphOptimizer - Generation num: 26 size: 55
# 2022-12-20 17:10:00,146 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=461.142>']
# 2022-12-20 17:10:00,148 - EvoGraphOptimizer - no improvements for 2 iterations
# 2022-12-20 17:10:00,151 - EvoGraphOptimizer - spent time: 14.7 min
# 2022-12-20 17:10:00,155 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:10:00,383 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:10:41,507 - EvoGraphOptimizer - Generation num: 27 size: 55
# 2022-12-20 17:10:41,509 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=461.142>']
# 2022-12-20 17:10:41,512 - EvoGraphOptimizer - no improvements for 3 iterations
# 2022-12-20 17:10:41,515 - EvoGraphOptimizer - spent time: 15.4 min
# 2022-12-20 17:10:41,518 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:10:41,762 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:11:20,930 - EvoGraphOptimizer - Generation num: 28 size: 55
# 2022-12-20 17:11:20,932 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=461.142>']
# 2022-12-20 17:11:20,936 - EvoGraphOptimizer - no improvements for 4 iterations
# 2022-12-20 17:11:20,938 - EvoGraphOptimizer - spent time: 16.1 min
# 2022-12-20 17:11:20,941 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:11:21,209 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:11:59,594 - EvoGraphOptimizer - Generation num: 29 size: 55
# 2022-12-20 17:11:59,596 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=460.111>']
# 2022-12-20 17:11:59,598 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:11:59,841 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:12:41,469 - EvoGraphOptimizer - Generation num: 30 size: 55
# 2022-12-20 17:12:41,471 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=459.518>']
# 2022-12-20 17:12:41,475 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:12:41,741 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:13:30,028 - EvoGraphOptimizer - Generation num: 31 size: 55
# 2022-12-20 17:13:30,030 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=458.615>']
# 2022-12-20 17:13:30,032 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:13:30,290 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:14:14,005 - EvoGraphOptimizer - Generation num: 32 size: 55
# 2022-12-20 17:14:14,007 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=458.423>']
# 2022-12-20 17:14:14,009 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:14:14,345 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:14:57,854 - EvoGraphOptimizer - Generation num: 33 size: 55
# 2022-12-20 17:14:57,862 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=458.423>']
# 2022-12-20 17:14:57,864 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 17:14:57,867 - EvoGraphOptimizer - spent time: 19.7 min
# 2022-12-20 17:14:57,870 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:14:58,236 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:16:00,969 - EvoGraphOptimizer - Generation num: 34 size: 55
# 2022-12-20 17:16:00,971 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=458.299>']
# 2022-12-20 17:16:00,974 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:16:01,537 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:16:43,432 - EvoGraphOptimizer - Generation num: 35 size: 55
# 2022-12-20 17:16:43,434 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=454.885>']
# 2022-12-20 17:16:43,436 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:16:43,646 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:17:26,533 - EvoGraphOptimizer - Generation num: 36 size: 55
# 2022-12-20 17:17:26,534 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=454.628>']
# 2022-12-20 17:17:26,537 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:17:26,752 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:18:16,135 - EvoGraphOptimizer - Generation num: 37 size: 55
# 2022-12-20 17:18:16,137 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=454.360>']
# 2022-12-20 17:18:16,138 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:18:16,338 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:19:01,438 - EvoGraphOptimizer - Generation num: 38 size: 55
# 2022-12-20 17:19:01,440 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=454.360>']
# 2022-12-20 17:19:01,442 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 17:19:01,446 - EvoGraphOptimizer - spent time: 23.7 min
# 2022-12-20 17:19:01,449 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:19:01,689 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:19:54,227 - EvoGraphOptimizer - Generation num: 39 size: 55
# 2022-12-20 17:19:54,229 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=454.197>']
# 2022-12-20 17:19:54,231 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:19:54,458 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:20:51,446 - EvoGraphOptimizer - Generation num: 40 size: 55
# 2022-12-20 17:20:51,448 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=452.509>']
# 2022-12-20 17:20:51,450 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:20:51,670 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:21:46,483 - EvoGraphOptimizer - Generation num: 41 size: 55
# 2022-12-20 17:21:46,485 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=452.509>']
# 2022-12-20 17:21:46,488 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 17:21:46,492 - EvoGraphOptimizer - spent time: 26.5 min
# 2022-12-20 17:21:46,495 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:21:46,749 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:22:50,456 - EvoGraphOptimizer - Generation num: 42 size: 55
# 2022-12-20 17:22:50,458 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=452.509>']
# 2022-12-20 17:22:50,461 - EvoGraphOptimizer - no improvements for 2 iterations
# 2022-12-20 17:22:50,464 - EvoGraphOptimizer - spent time: 27.6 min
# 2022-12-20 17:22:50,468 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:22:50,698 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:23:51,709 - EvoGraphOptimizer - Generation num: 43 size: 55
# 2022-12-20 17:23:51,712 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=452.027>']
# 2022-12-20 17:23:51,715 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:23:52,130 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:25:10,675 - EvoGraphOptimizer - Generation num: 44 size: 55
# 2022-12-20 17:25:10,677 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=452.027>']
# 2022-12-20 17:25:10,679 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 17:25:10,681 - EvoGraphOptimizer - spent time: 29.9 min
# 2022-12-20 17:25:10,684 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:25:10,921 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:26:11,977 - EvoGraphOptimizer - Generation num: 45 size: 55
# 2022-12-20 17:26:11,979 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=452.027>']
# 2022-12-20 17:26:11,981 - EvoGraphOptimizer - no improvements for 2 iterations
# 2022-12-20 17:26:11,983 - EvoGraphOptimizer - spent time: 30.9 min
# 2022-12-20 17:26:11,988 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:26:12,240 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:27:28,488 - EvoGraphOptimizer - Generation num: 46 size: 55
# 2022-12-20 17:27:28,490 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=450.240>']
# 2022-12-20 17:27:28,493 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:27:28,928 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:28:34,745 - EvoGraphOptimizer - Generation num: 47 size: 55
# 2022-12-20 17:28:34,747 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=449.791>']
# 2022-12-20 17:28:34,750 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:28:35,197 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:29:45,615 - EvoGraphOptimizer - Generation num: 48 size: 55
# 2022-12-20 17:29:45,617 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=449.791>']
# 2022-12-20 17:29:45,619 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 17:29:45,622 - EvoGraphOptimizer - spent time: 34.5 min
# 2022-12-20 17:29:45,626 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:29:45,872 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:31:19,656 - EvoGraphOptimizer - Generation num: 49 size: 55
# 2022-12-20 17:31:19,658 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=449.791>']
# 2022-12-20 17:31:19,660 - EvoGraphOptimizer - no improvements for 2 iterations
# 2022-12-20 17:31:19,664 - EvoGraphOptimizer - spent time: 36.0 min
# 2022-12-20 17:31:19,667 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:31:19,903 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:32:29,621 - EvoGraphOptimizer - Generation num: 50 size: 55
# 2022-12-20 17:32:29,623 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=448.205>']
# 2022-12-20 17:32:29,626 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:32:29,855 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:33:41,790 - EvoGraphOptimizer - Generation num: 51 size: 55
# 2022-12-20 17:33:41,792 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=448.205>']
# 2022-12-20 17:33:41,794 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 17:33:41,799 - EvoGraphOptimizer - spent time: 38.4 min
# 2022-12-20 17:33:41,803 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:33:42,115 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:34:41,938 - EvoGraphOptimizer - Generation num: 52 size: 55
# 2022-12-20 17:34:41,940 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=448.171>']
# 2022-12-20 17:34:41,943 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:34:42,206 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:35:46,359 - EvoGraphOptimizer - Generation num: 53 size: 55
# 2022-12-20 17:35:46,360 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=447.977>']
# 2022-12-20 17:35:46,363 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:35:46,611 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:36:50,193 - EvoGraphOptimizer - Generation num: 54 size: 55
# 2022-12-20 17:36:50,195 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=447.977>']
# 2022-12-20 17:36:50,197 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 17:36:50,200 - EvoGraphOptimizer - spent time: 41.6 min
# 2022-12-20 17:36:50,204 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:36:50,533 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:37:50,937 - EvoGraphOptimizer - Generation num: 55 size: 55
# 2022-12-20 17:37:50,939 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=447.977>']
# 2022-12-20 17:37:50,941 - EvoGraphOptimizer - no improvements for 2 iterations
# 2022-12-20 17:37:50,945 - EvoGraphOptimizer - spent time: 42.6 min
# 2022-12-20 17:37:50,949 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:37:51,252 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:38:55,313 - EvoGraphOptimizer - Generation num: 56 size: 55
# 2022-12-20 17:38:55,319 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=447.975>']
# 2022-12-20 17:38:55,323 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:38:55,844 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:40:08,992 - EvoGraphOptimizer - Generation num: 57 size: 55
# 2022-12-20 17:40:08,994 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=447.975>']
# 2022-12-20 17:40:08,998 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 17:40:09,001 - EvoGraphOptimizer - spent time: 44.9 min
# 2022-12-20 17:40:09,005 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:40:09,390 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:41:26,217 - EvoGraphOptimizer - Generation num: 58 size: 55
# 2022-12-20 17:41:26,219 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=447.975>']
# 2022-12-20 17:41:26,228 - EvoGraphOptimizer - no improvements for 2 iterations
# 2022-12-20 17:41:26,231 - EvoGraphOptimizer - spent time: 46.2 min
# 2022-12-20 17:41:26,234 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:41:26,918 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:42:47,554 - EvoGraphOptimizer - Generation num: 59 size: 55
# 2022-12-20 17:42:47,559 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=447.796>']
# 2022-12-20 17:42:47,562 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:42:47,880 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:43:54,987 - EvoGraphOptimizer - Generation num: 60 size: 55
# 2022-12-20 17:43:54,989 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=447.248>']
# 2022-12-20 17:43:54,992 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:43:55,307 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:45:19,195 - EvoGraphOptimizer - Generation num: 61 size: 55
# 2022-12-20 17:45:19,198 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=447.248>']
# 2022-12-20 17:45:19,201 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 17:45:19,205 - EvoGraphOptimizer - spent time: 50.0 min
# 2022-12-20 17:45:19,210 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:45:19,819 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:46:24,485 - EvoGraphOptimizer - Generation num: 62 size: 55
# 2022-12-20 17:46:24,488 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=446.666>']
# 2022-12-20 17:46:24,490 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:46:24,844 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:47:23,938 - EvoGraphOptimizer - Generation num: 63 size: 55
# 2022-12-20 17:47:23,940 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=446.318>']
# 2022-12-20 17:47:23,944 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:47:24,259 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:48:19,856 - EvoGraphOptimizer - Generation num: 64 size: 55
# 2022-12-20 17:48:19,858 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=445.886>']
# 2022-12-20 17:48:19,860 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:48:20,158 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:49:13,509 - EvoGraphOptimizer - Generation num: 65 size: 55
# 2022-12-20 17:49:13,509 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=445.886>']
# 2022-12-20 17:49:13,509 - EvoGraphOptimizer - no improvements for 1 iterations
# 2022-12-20 17:49:13,519 - EvoGraphOptimizer - spent time: 53.9 min
# 2022-12-20 17:49:13,523 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:49:13,879 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:49:56,073 - EvoGraphOptimizer - Generation num: 66 size: 55
# 2022-12-20 17:49:56,073 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=445.886>']
# 2022-12-20 17:49:56,089 - EvoGraphOptimizer - no improvements for 2 iterations
# 2022-12-20 17:49:56,093 - EvoGraphOptimizer - spent time: 54.7 min
# 2022-12-20 17:49:56,096 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:49:56,296 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:50:37,144 - EvoGraphOptimizer - Generation num: 67 size: 55
# 2022-12-20 17:50:37,144 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=445.886>']
# 2022-12-20 17:50:37,160 - EvoGraphOptimizer - no improvements for 3 iterations
# 2022-12-20 17:50:37,163 - EvoGraphOptimizer - spent time: 55.3 min
# 2022-12-20 17:50:37,164 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:50:37,413 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:51:16,021 - EvoGraphOptimizer - Generation num: 68 size: 55
# 2022-12-20 17:51:16,021 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=445.886>']
# 2022-12-20 17:51:16,021 - EvoGraphOptimizer - no improvements for 4 iterations
# 2022-12-20 17:51:16,028 - EvoGraphOptimizer - spent time: 56.0 min
# 2022-12-20 17:51:16,031 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:51:16,294 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:51:52,818 - EvoGraphOptimizer - Generation num: 69 size: 55
# 2022-12-20 17:51:52,818 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=445.886>']
# 2022-12-20 17:51:52,833 - EvoGraphOptimizer - no improvements for 5 iterations
# 2022-12-20 17:51:52,833 - EvoGraphOptimizer - spent time: 56.6 min
# 2022-12-20 17:51:52,839 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:51:53,079 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:52:32,389 - EvoGraphOptimizer - Generation num: 70 size: 55
# 2022-12-20 17:52:32,389 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=445.886>']
# 2022-12-20 17:52:32,389 - EvoGraphOptimizer - no improvements for 6 iterations
# 2022-12-20 17:52:32,401 - EvoGraphOptimizer - spent time: 57.3 min
# 2022-12-20 17:52:32,405 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:52:32,652 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:53:15,889 - EvoGraphOptimizer - Generation num: 71 size: 55
# 2022-12-20 17:53:15,889 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=445.886>']
# 2022-12-20 17:53:15,889 - EvoGraphOptimizer - no improvements for 7 iterations
# 2022-12-20 17:53:15,905 - EvoGraphOptimizer - spent time: 58.0 min
# 2022-12-20 17:53:15,908 - EvoGraphOptimizer - Next population size: 55; max graph depth: 100
# 2022-12-20 17:53:16,157 - MultiprocessingDispatcher - Number of used CPU's: 1
# 2022-12-20 17:54:09,615 - EvoGraphOptimizer - Generation num: 72 size: 55
# 2022-12-20 17:54:09,622 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=445.886>']
# 2022-12-20 17:54:09,629 - EvoGraphOptimizer - no improvements for 8 iterations
# 2022-12-20 17:54:09,633 - EvoGraphOptimizer - spent time: 58.9 min
# 2022-12-20 17:54:09,638 - GroupedCondition - Optimisation finished: Early stopping timeout criteria was satisfied
# Generations:   0%|          | 1/1000 [58:52<?, ?gen/s]
# 2022-12-20 17:54:09,650 - OptimisationTimer - Composition time: 58.877 min
# 2022-12-20 17:54:09,653 - EvoGraphOptimizer - Generation num: 73 size: 1
# 2022-12-20 17:54:09,660 - EvoGraphOptimizer - Best individuals: HallOfFame archive fitness (1): ['<custom=445.886>']
# 2022-12-20 17:54:09,663 - EvoGraphOptimizer - no improvements for 9 iterations
# 2022-12-20 17:54:09,667 - EvoGraphOptimizer - spent time: 58.9 min
# Score of optimized graph =  446.06891389343707
# SHD of optimized graph =  14
